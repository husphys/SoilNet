# %% [markdown]
# # P3 — pure MobileViTv2 + VICReg + LI (validation BESTREG)
#
# This notebook is a fresh-kernel, sequential **Run All** workflow for
# `P3_MOBILEVITV2_VICREG_LI_BESTREG`. It never constructs a test dataset or test
# loader. The held-out test set remains closed unless P3 is later frozen into the
# separate final-test workflow.
#
# The supervised selection score is
#
# $$R_{\mathrm{val}}=\frac{RMSE_{\mathrm{SM0}}+RMSE_{\mathrm{SM20}}}{2}.$$
#
# All 60 supervised epochs run; validation-best selection is not early stopping.

# %% [markdown]
# ## 1. Environment check and Run-All controls

# %%
import os
os.environ.setdefault("CUBLAS_WORKSPACE_CONFIG", ":4096:8")

from pathlib import Path
import csv
import json
import platform
import shutil
import subprocess
import sys
import time
from datetime import datetime, timezone

def find_repo(start: Path) -> Path:
    for candidate in (start.resolve(), *start.resolve().parents):
        if (candidate / "pyproject.toml").is_file() and (candidate / "src/soilnet").is_dir():
            return candidate
    raise RuntimeError("STOP: run this notebook from inside the SoilNet checkout")

REPO = find_repo(Path.cwd())
sys.path.insert(0, str(REPO / "src"))
sys.path.insert(0, str(REPO))

import pandas as pd
import timm
import torch
import torchvision
import yaml
from IPython.display import display

from soilnet.evaluation.predictions import prediction_rows_and_metrics
from soilnet.final_protocol import current_git_commit
from soilnet.io import load_yaml, resolve_paths, resolve_run_artifact_root, sha256_file, write_json
from soilnet.models import build_frozen_model, build_model
from soilnet.training.engine import build_val_loader, run_one_batch_preflight, train_experiment
from soilnet.training.vicreg import (
    reconcile_resolved_p3_before_ssl,
    reconcile_resolved_p3_config,
    pretrain_mobilevitv2_vicreg,
    run_vicreg_one_batch_preflight,
    validate_or_archive_stale_supervised_state,
    verify_mobilevitv2_vicreg,
)
from soilnet.utils import load_experiment_context
from scripts.run_p3_mobilevitv2_vicreg import (
    P2_CONFIG, P3_CONFIG, PROTECTED_EXPERIMENTS, SUPERVISED_MATCH_FIELDS,
    comparison_rows, hash_tree, preflight_protocol,
)

# The completed epoch-80 SSL checkpoint is now frozen.  Keep this False for
# subsequent Run All executions so the notebook can only verify and reuse it.
RUN_SSL_PRETRAINING = False
RESUME_SUPERVISED_IF_AVAILABLE = True

if not torch.cuda.is_available():
    raise RuntimeError("GPU_BLOCKED: P3 requires CUDA; no CPU fallback is authorized")

print({
    "repo": str(REPO),
    "git_commit": current_git_commit(REPO),
    "git_dirty": bool(subprocess.check_output(["git", "status", "--porcelain"], cwd=REPO, text=True).strip()),
    "python": platform.python_version(),
    "pytorch": torch.__version__,
    "torchvision": torchvision.__version__,
    "timm": timm.__version__,
    "cuda_available": torch.cuda.is_available(),
    "gpu_name": torch.cuda.get_device_name(0),
    "RUN_SSL_PRETRAINING": RUN_SSL_PRETRAINING,
    "TEST_LOADER_INSTANTIATED": False,
})

# %% [markdown]
# ## 2. Path and locked-config check

# %%
p2 = load_yaml(P2_CONFIG)
p3 = load_yaml(P3_CONFIG)
p3_source_config_sha256 = sha256_file(P3_CONFIG)
paths = resolve_paths()
run_root = resolve_run_artifact_root()
experiment_root = run_root / p3["experiment_id"]
supervised_dir = experiment_root / "supervised"
p2_dir = run_root / p2["output_dir"]
stale_archive_root = run_root.parent / "soilnet_stale_p3"

required_p2 = (p2_dir / "run_metadata.json", p2_dir / "validation_metrics.json")
missing_p2 = [str(path) for path in required_p2 if not path.is_file()]
if missing_p2:
    raise RuntimeError(f"STOP: required frozen P2 validation artifacts are missing: {missing_p2}")
if p3["experiment_id"] != "P3_MOBILEVITV2_VICREG_LI_BESTREG":
    raise RuntimeError("STOP: unexpected P3 experiment ID")
if p3["timm_model_name"] != "mobilevitv2_050.cvnets_in1k":
    raise RuntimeError("STOP: MobileViTv2 model tag changed")
if p3.get("ssl_checkpoint") is not None:
    raise RuntimeError("STOP: source config must not point to a pre-existing SSL checkpoint")
if p3["initialization_provenance"].get("soilnet_vicreg_checkpoint_loaded") is not False:
    raise RuntimeError("STOP: SoilNet VICReg checkpoints are prohibited for P3")

source_context = load_experiment_context(P3_CONFIG)
pre_ssl_resolved_reconciliation = reconcile_resolved_p3_before_ssl(
    config=p3,
    config_sha256=p3_source_config_sha256,
    experiment_root=experiment_root,
    stale_archive_root=stale_archive_root,
)
print({
    "DATA_ROOT": str(paths["data_root"]),
    "CHECKPOINT_ROOT": str(paths["checkpoint_root"]),
    "RUN_ARTIFACT_ROOT": str(run_root),
    "experiment_root": str(experiment_root),
    "experiment_id": p3["experiment_id"],
    "model_name": p3["timm_model_name"],
    "initialization_source": p3["initialization_provenance"]["source"],
    "source_config_sha256": p3_source_config_sha256,
    "seed": p3["seed"],
    "epochs": p3["epochs"],
    "batch_size": p3["batch_size"],
    "optimizer": p3["optimizer"],
    "learning_rate": p3["learning_rate"],
    "LI_enabled": p3["use_li"],
    "TEST_LOADER_INSTANTIATED": False,
    "PRE_SSL_RESOLVED_CONFIG_STATUS": pre_ssl_resolved_reconciliation["status"],
})

# %% [markdown]
# ## 3. Dataset and split verification (metadata only; no test dataset)

# %%
print({
    "dataset_manifest": str(source_context.manifest_path),
    "dataset_manifest_sha256": source_context.manifest_sha256,
    "split_manifest": str(source_context.split_path),
    "split_sha256": source_context.split_sha256,
    "train_count": p3["split_counts"]["train"],
    "validation_count": p3["split_counts"]["validation"],
    "held_out_test_count_metadata_only": p3["split_counts"]["test"],
    "unlabeled_image_count": p3["vicreg_pretraining"]["expected_image_count"],
    "TEST_LOADER_INSTANTIATED": False,
})

# %% [markdown]
# ## 4. P2/P3 protocol comparison — only initialization/VICReg fields may differ

# %%
protocol_report = preflight_protocol(p2, p3, paths["checkpoint_root"])
allowed_difference_fields = {
    "experiment_id", "protocol_revision", "protocol_version", "ablation_type",
    "scientific_question", "architecture_role", "initialization", "ssl", "mu",
    "initialization_provenance", "vicreg_pretraining", "output_dir",
}
display_fields = list(dict.fromkeys([
    "experiment_id", "architecture", "timm_model_name", "initialization", "ssl", "mu",
    *SUPERVISED_MATCH_FIELDS, "vicreg_pretraining", "output_dir",
]))
diff_rows = []
for field in display_fields:
    same = p2.get(field) == p3.get(field)
    status = "MATCH" if same else ("ALLOWED_INITIALIZATION_DIFF" if field in allowed_difference_fields else "FORBIDDEN_DIFF")
    diff_rows.append({"field": field, "P2": p2.get(field), "P3": p3.get(field), "status": status})
diff_table = pd.DataFrame(diff_rows)
display(diff_table)
forbidden = diff_table[diff_table["status"] == "FORBIDDEN_DIFF"]
if not forbidden.empty:
    raise RuntimeError(f"STOP: forbidden P2/P3 differences: {forbidden['field'].tolist()}")
print(json.dumps(protocol_report, indent=2))

# %% [markdown]
# ## 5. Model construction and protected-artifact snapshot

# %%
protected_before = {name: hash_tree(run_root / name) for name in PROTECTED_EXPERIMENTS}
torch.manual_seed(int(p3["seed"]))
architecture_probe, _ = build_model(p3, paths["checkpoint_root"], pretrained_override=False)
parameter_count = sum(parameter.numel() for parameter in architecture_probe.parameters())
if parameter_count != 1189189:
    raise RuntimeError(f"STOP: P3 parameter count changed: {parameter_count}")
print({
    "model_class": architecture_probe.__class__.__name__,
    "model_name": p3["timm_model_name"],
    "parameters": parameter_count,
    "LI_enabled": architecture_probe.use_light,
    "regression_outputs": architecture_probe.reg_head[-1].out_features,
    "classification_outputs": architecture_probe.cls_head[-1].out_features,
    "protected_experiments_snapshotted": list(protected_before),
    "TEST_LOADER_INSTANTIATED": False,
})
del architecture_probe

# %% [markdown]
# ## 6. Engineering preflight: VICReg loss/backward and supervised train/validation batches

# %%
vicreg_preflight = run_vicreg_one_batch_preflight(
    config=p3, repo=REPO, data_root=paths["data_root"], device="cuda"
)
p2_context = load_experiment_context(P2_CONFIG)
supervised_pipeline_preflight = run_one_batch_preflight(p2_context, device="cuda")
if not vicreg_preflight["loss_finite"] or supervised_pipeline_preflight["status"] != "PASS":
    raise RuntimeError("STOP: engineering preflight failed")
print(json.dumps({
    "VICREG_ONE_BATCH_PREFLIGHT": vicreg_preflight,
    "SUPERVISED_TRAIN_VALIDATION_PREFLIGHT": supervised_pipeline_preflight,
    "TEST_LOADER_INSTANTIATED": False,
}, indent=2))

# %% [markdown]
# ## 7. VICReg pretraining or exact verified reuse

# %%
experiment_root.mkdir(parents=True, exist_ok=True)
source_snapshot = experiment_root / "source_config.yaml"
if source_snapshot.exists() and source_snapshot.read_bytes() != P3_CONFIG.read_bytes():
    raise RuntimeError("STOP: existing P3 source-config snapshot differs")
if not source_snapshot.exists():
    shutil.copyfile(P3_CONFIG, source_snapshot)
write_json(experiment_root / "p2_p3_preflight_report.json", protocol_report)
write_json(experiment_root / "protected_artifacts_before_notebook.json", protected_before)

if RUN_SSL_PRETRAINING:
    ssl_metadata = pretrain_mobilevitv2_vicreg(
        config=p3,
        config_sha256=p3_source_config_sha256,
        repo=REPO,
        data_root=paths["data_root"],
        experiment_root=experiment_root,
        run_ssl_pretraining=RUN_SSL_PRETRAINING,
    )
    ssl_action = "PRETRAINED_OR_VERIFIED_COMPLETED_REUSE"
else:
    ssl_metadata = verify_mobilevitv2_vicreg(
        config=p3,
        config_sha256=p3_source_config_sha256,
        experiment_root=experiment_root,
    )
    ssl_action = "STRICT_VERIFIED_REUSE"

print({
    "EXPERIMENT_ID": p3["experiment_id"],
    "CONFIG_SHA256": p3_source_config_sha256,
    "UNLABELED_MANIFEST_SHA256": ssl_metadata["unlabeled_manifest_sha256"],
    "SPLIT_SHA256": p3["split_sha256"],
    "TIMM_MODEL_NAME": p3["timm_model_name"],
    "RUN_SSL_PRETRAINING": RUN_SSL_PRETRAINING,
    "SSL_RESUME_STATUS": ssl_metadata.get("resume_resolution", {}).get("status", ssl_action),
    "SSL_START_EPOCH": ssl_metadata.get("resume_resolution", {}).get("start_epoch"),
    "TRAIN_COUNT": p3["split_counts"]["train"],
    "VALIDATION_COUNT": p3["split_counts"]["validation"],
    "SSL_ACTION": ssl_action,
    "SSL_CHECKPOINT": ssl_metadata["encoder_checkpoint_path"],
    "SSL_CHECKPOINT_SHA256": ssl_metadata["encoder_checkpoint_sha256"],
    "SSL_EPOCH": ssl_metadata["epochs"],
    "SSL_CONFIG_SHA256": ssl_metadata["source_config_sha256"],
    "UNLABELED_MANIFEST_SHA256": ssl_metadata["unlabeled_manifest_sha256"],
    "TEST_LOADER_INSTANTIATED": False,
})

# %% [markdown]
# ## 8. Reconcile resolved config, supervised state, and strict-load the P3 encoder

# %%
# This cell is also the supported recovery entry point in an already-running
# kernel. Reload edited local modules so cell 8 onward cannot retain the stale
# implementations imported before the resolved-config reconciliation fix.
import importlib
import soilnet.models.factory as _factory_module
import soilnet.models as _models_module
import soilnet.training.engine as _engine_module
import soilnet.training.vicreg as _vicreg_module
import soilnet.utils.experiment as _experiment_module

importlib.invalidate_caches()
_factory_module = importlib.reload(_factory_module)
_models_module = importlib.reload(_models_module)
_experiment_module = importlib.reload(_experiment_module)
_vicreg_module = importlib.reload(_vicreg_module)
_engine_module = importlib.reload(_engine_module)

build_frozen_model = _models_module.build_frozen_model
build_model = _models_module.build_model
build_val_loader = _engine_module.build_val_loader
run_one_batch_preflight = _engine_module.run_one_batch_preflight
train_experiment = _engine_module.train_experiment
load_experiment_context = _experiment_module.load_experiment_context
reconcile_resolved_p3_config = _vicreg_module.reconcile_resolved_p3_config
validate_or_archive_stale_supervised_state = _vicreg_module.validate_or_archive_stale_supervised_state

stale_archive_root = run_root.parent / "soilnet_stale_p3"
resolved_reconciliation = reconcile_resolved_p3_config(
    config=p3,
    config_sha256=p3_source_config_sha256,
    experiment_root=experiment_root,
    stale_archive_root=stale_archive_root,
)
resolved_config = Path(resolved_reconciliation["resolved_config_path"])
print("resolved_config diff")
display(pd.DataFrame(resolved_reconciliation["field_diff"], columns=[
    "key", "existing_value", "current_expected_value"
]))
print(json.dumps(resolved_reconciliation, indent=2))
context = load_experiment_context(resolved_config)
resolved = context.config
if context.config["ssl_checkpoint"]["sha256"] != ssl_metadata["encoder_checkpoint_sha256"]:
    raise RuntimeError("STOP: resolved context does not reference the verified epoch-80 SSL checkpoint")

supervised_state_resolution = validate_or_archive_stale_supervised_state(
    resolved_config=context.config,
    resolved_config_sha256=context.config_sha256,
    experiment_root=experiment_root,
    stale_archive_root=stale_archive_root,
)
print(json.dumps({"SUPERVISED_STATE_RESOLUTION": supervised_state_resolution}, indent=2))

strict_preflight = run_one_batch_preflight(context, device="cuda")
if strict_preflight["status"] != "PASS" or strict_preflight["vicreg_checkpoint_loaded"] is not True:
    raise RuntimeError("STOP: strict P3 encoder load or supervised one-batch preflight failed")
write_json(experiment_root / "supervised_preflight_report.json", strict_preflight)
print({
    "experiment_id": context.config["experiment_id"],
    "model_name": context.config["timm_model_name"],
    "initialization_source": strict_preflight["load_report"]["source_kind"],
    "VICREG_CHECKPOINT_SHA256": strict_preflight["load_report"]["checkpoint_sha256"],
    "matched_backbone_keys": strict_preflight["load_report"]["matched_keys"],
    "parameters": parameter_count,
    "seed": context.config["seed"],
    "epochs": context.config["epochs"],
    "batch_size": context.config["batch_size"],
    "optimizer": context.config["optimizer"],
    "learning_rate": context.config["learning_rate"],
    "LI_enabled": context.config["use_li"],
    "TEST_LOADER_INSTANTIATED": False,
})
# Out:
# resolved_config diff
# Empty DataFrame
# Columns: [key, existing_value, current_expected_value]
# Index: []
# {
#   "status": "MATCHED_CURRENT",
#   "resolved_config_path": "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/resolved_config.yaml",
#   "field_diff": [],
#   "old_resolved_config_sha256": "563efb512c3fbc703aad5fae42c1dfc4d8c07adee8bbc729c83d1b74890ebc43",
#   "new_resolved_config_sha256": "563efb512c3fbc703aad5fae42c1dfc4d8c07adee8bbc729c83d1b74890ebc43",
#   "ssl_checkpoint_path": "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/mobilevitv2_vicreg_encoder_final.pth",
#   "ssl_checkpoint_sha256": "32a1a62233d39bf6d5de5f803e7781be81e6a96851efc1531f87ec6f80ec5580",
#   "ssl_completed_epoch": 80,
#   "ssl_identity_verification": "PASS",
#   "test_loader_instantiated": false
# }
# {
#   "SUPERVISED_STATE_RESOLUTION": {
#     "status": "NO_SUPERVISED_RESUME",
#     "start_epoch": 1,
#     "test_loader_instantiated": false
#   }
# }
# {'experiment_id': 'P3_MOBILEVITV2_VICREG_LI_BESTREG', 'model_name': 'mobilevitv2_050.cvnets_in1k', 'initialization_source': 'mobilevitv2_vicreg_ssl', 'VICREG_CHECKPOINT_SHA256': '32a1a62233d39bf6d5de5f803e7781be81e6a96851efc1531f87ec6f80ec5580', 'matched_backbone_keys': 267, 'parameters': 1189189, 'seed': 20260905, 'epochs': 60, 'batch_size': 32, 'optimizer': 'Adam', 'learning_rate': 0.0001, 'LI_enabled': True, 'TEST_LOADER_INSTANTIATED': False}

# %% [markdown]
# ## 9. Supervised fine-tuning — 60 epochs, validation BESTREG, no early stopping

# %%
supervised_started = time.monotonic()
completed_metadata_path = supervised_dir / "run_metadata.json"
if completed_metadata_path.is_file():
    run_metadata = json.loads(completed_metadata_path.read_text(encoding="utf-8"))
    if run_metadata.get("training_completed") is not True:
        raise RuntimeError("STOP: invalid existing supervised metadata")
    if sha256_file(Path(run_metadata["primary_checkpoint_path"])) != run_metadata["primary_checkpoint_sha256"]:
        raise RuntimeError("STOP: existing P3 best-checkpoint SHA256 mismatch")
    supervised_action = "STRICT_VERIFIED_COMPLETED_REUSE"
else:
    run_metadata = train_experiment(context, resume_if_available=RESUME_SUPERVISED_IF_AVAILABLE)
    supervised_action = "TRAINED_OR_RESUMED_TO_60_EPOCHS"
supervised_elapsed_this_run = time.monotonic() - supervised_started
if run_metadata["epochs_completed"] != 60:
    raise RuntimeError("STOP: P3 supervised training did not complete all 60 epochs")
print({
    "SUPERVISED_ACTION": supervised_action,
    "epochs_completed": run_metadata["epochs_completed"],
    "best_epoch": run_metadata["best_epoch"],
    "best_mean_validation_RMSE": run_metadata["best_mean_validation_RMSE"],
    "best_checkpoint": run_metadata["primary_checkpoint_path"],
    "best_checkpoint_sha256": run_metadata["primary_checkpoint_sha256"],
    "TEST_LOADER_INSTANTIATED": False,
})
# Out:
# BEST REGRESSION UPDATED | epoch=1 | mean_RMSE=34.7732 | SM0=37.2187 | SM20=32.3277
# {"epoch": 1, "train_total_loss": 2.57817067341371, "train_regression_loss": 0.2946441481736573, "train_classification_loss": 2.283526512709531, "validation_total_loss": 2.421725702285767, "SM0_RMSE": 37.218725182262006, "SM0_MAE": 29.010957840714074, "SM0_R2": -0.5821697182243322, "SM20_RMSE": 32.32773355303335, "SM20_MAE": 24.809040168319605, "SM20_R2": -0.19761905882262942, "mean_validation_RMSE": 34.77322936764767, "current_best_epoch": 1, "current_best_mean_validation_RMSE": 34.77322936764767, "best_checkpoint_updated": true, "classification_accuracy": 0.16262975778546712, "Macro-F1": 0.13993839199031594, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=2 | mean_RMSE=23.0784 | SM0=23.7815 | SM20=22.3753
# {"epoch": 2, "train_total_loss": 2.321082678708163, "train_regression_loss": 0.10194416902959347, "train_classification_loss": 2.2191385084932502, "validation_total_loss": 2.3108821153640746, "SM0_RMSE": 23.781516140268412, "SM0_MAE": 18.706342938037068, "SM0_R2": 0.35403474582000183, "SM20_RMSE": 22.37534309579721, "SM20_MAE": 17.905383288241588, "SM20_R2": 0.4262699603336353, "mean_validation_RMSE": 23.07842961803281, "current_best_epoch": 2, "current_best_mean_validation_RMSE": 23.07842961803281, "best_checkpoint_updated": true, "classification_accuracy": 0.17993079584775087, "Macro-F1": 0.15025460677408048, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=3 | mean_RMSE=19.2734 | SM0=19.7531 | SM20=18.7937
# {"epoch": 3, "train_total_loss": 2.1905613975091414, "train_regression_loss": 0.055971140041947365, "train_classification_loss": 2.134590268135071, "validation_total_loss": 2.1594449996948244, "SM0_RMSE": 19.753099640260878, "SM0_MAE": 15.268696883970478, "SM0_R2": 0.5543431463018165, "SM20_RMSE": 18.793652162224383, "SM20_MAE": 14.495648669536552, "SM20_R2": 0.595246556842346, "mean_validation_RMSE": 19.27337590124263, "current_best_epoch": 3, "current_best_mean_validation_RMSE": 19.27337590124263, "best_checkpoint_updated": true, "classification_accuracy": 0.2664359861591695, "Macro-F1": 0.24336266256845648, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=4 | mean_RMSE=17.6772 | SM0=17.7448 | SM20=17.6097
# {"epoch": 4, "train_total_loss": 2.0753133513710718, "train_regression_loss": 0.03975320620123635, "train_classification_loss": 2.0355601500381124, "validation_total_loss": 2.002970886230469, "SM0_RMSE": 17.74480705094758, "SM0_MAE": 13.736214451311369, "SM0_R2": 0.6403561453669354, "SM20_RMSE": 17.609665315402243, "SM20_MAE": 13.54299387882325, "SM20_R2": 0.6446384899247248, "mean_validation_RMSE": 17.677236183174912, "current_best_epoch": 4, "current_best_mean_validation_RMSE": 17.677236183174912, "best_checkpoint_updated": true, "classification_accuracy": 0.2837370242214533, "Macro-F1": 0.23027092422488601, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=5 | mean_RMSE=16.4477 | SM0=16.4591 | SM20=16.4362
# {"epoch": 5, "train_total_loss": 1.9366084987466985, "train_regression_loss": 0.030957632105458866, "train_classification_loss": 1.905650862238624, "validation_total_loss": 1.8528240203857422, "SM0_RMSE": 16.459054617473754, "SM0_MAE": 12.699694275856018, "SM0_R2": 0.6905860758692932, "SM20_RMSE": 16.436247739730774, "SM20_MAE": 12.559463441062551, "SM20_R2": 0.6904195407974243, "mean_validation_RMSE": 16.447651178602264, "current_best_epoch": 5, "current_best_mean_validation_RMSE": 16.447651178602264, "best_checkpoint_updated": true, "classification_accuracy": 0.28719723183391005, "Macro-F1": 0.2357909826460976, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=6 | mean_RMSE=16.0775 | SM0=16.3012 | SM20=15.8538
# {"epoch": 6, "train_total_loss": 1.8021047846837477, "train_regression_loss": 0.02567358585921201, "train_classification_loss": 1.7764312001791867, "validation_total_loss": 1.7296206593513488, "SM0_RMSE": 16.301180760671677, "SM0_MAE": 12.11664776241078, "SM0_R2": 0.6964933525592953, "SM20_RMSE": 15.853797739125731, "SM20_MAE": 11.855303223879693, "SM20_R2": 0.7119719333944609, "mean_validation_RMSE": 16.077489249898704, "current_best_epoch": 6, "current_best_mean_validation_RMSE": 16.077489249898704, "best_checkpoint_updated": true, "classification_accuracy": 0.314878892733564, "Macro-F1": 0.25423134136820613, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=7 | mean_RMSE=15.6493 | SM0=15.9419 | SM20=15.3567
# {"epoch": 7, "train_total_loss": 1.6745869734070518, "train_regression_loss": 0.024222239386290312, "train_classification_loss": 1.6503647294911472, "validation_total_loss": 1.6300025463104248, "SM0_RMSE": 15.941885114357294, "SM0_MAE": 11.845374864690443, "SM0_R2": 0.7097251354507318, "SM20_RMSE": 15.356694603319013, "SM20_MAE": 11.8296417464022, "SM20_R2": 0.7297512598860978, "mean_validation_RMSE": 15.649289858838154, "current_best_epoch": 7, "current_best_mean_validation_RMSE": 15.649289858838154, "best_checkpoint_updated": true, "classification_accuracy": 0.32525951557093424, "Macro-F1": 0.27832238073840554, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 8, "train_total_loss": 1.5857405960559845, "train_regression_loss": 0.02294273718937554, "train_classification_loss": 1.5627978498285466, "validation_total_loss": 1.5632641673088075, "SM0_RMSE": 16.078708077522318, "SM0_MAE": 11.278510276421544, "SM0_R2": 0.7047211222609226, "SM20_RMSE": 15.339789640817802, "SM20_MAE": 11.084586707121051, "SM20_R2": 0.7303459230427124, "mean_validation_RMSE": 15.70924885917006, "current_best_epoch": 7, "current_best_mean_validation_RMSE": 15.649289858838154, "best_checkpoint_updated": false, "classification_accuracy": 0.3460207612456747, "Macro-F1": 0.30830390002397134, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=9 | mean_RMSE=14.2788 | SM0=14.3474 | SM20=14.2102
# {"epoch": 9, "train_total_loss": 1.457885349338705, "train_regression_loss": 0.019074066732586784, "train_classification_loss": 1.4388112750920383, "validation_total_loss": 1.4672047674655915, "SM0_RMSE": 14.347423313891282, "SM0_MAE": 10.567128349752988, "SM0_R2": 0.7648863166686964, "SM20_RMSE": 14.210241284663196, "SM20_MAE": 10.76162554401015, "SM20_R2": 0.7685958799650606, "mean_validation_RMSE": 14.278832299277239, "current_best_epoch": 9, "current_best_mean_validation_RMSE": 14.278832299277239, "best_checkpoint_updated": true, "classification_accuracy": 0.39792387543252594, "Macro-F1": 0.3506282109241812, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=10 | mean_RMSE=13.9587 | SM0=14.1880 | SM20=13.7294
# {"epoch": 10, "train_total_loss": 1.3749243102290414, "train_regression_loss": 0.01732316598380831, "train_classification_loss": 1.357601138678464, "validation_total_loss": 1.4507876813411713, "SM0_RMSE": 14.188027420733766, "SM0_MAE": 10.477837390553168, "SM0_R2": 0.7700813931484969, "SM20_RMSE": 13.729440252624425, "SM20_MAE": 10.171439072665047, "SM20_R2": 0.7839900055644242, "mean_validation_RMSE": 13.958733836679095, "current_best_epoch": 10, "current_best_mean_validation_RMSE": 13.958733836679095, "best_checkpoint_updated": true, "classification_accuracy": 0.3875432525951557, "Macro-F1": 0.3629517026742622, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 11, "train_total_loss": 1.3278363631530241, "train_regression_loss": 0.01651466443118724, "train_classification_loss": 1.3113217015158047, "validation_total_loss": 1.3967122673988341, "SM0_RMSE": 14.207804714454848, "SM0_MAE": 10.36708399292507, "SM0_R2": 0.7694399597864323, "SM20_RMSE": 13.769103211612556, "SM20_MAE": 10.088660922429966, "SM20_R2": 0.7827401409160037, "mean_validation_RMSE": 13.988453963033702, "current_best_epoch": 10, "current_best_mean_validation_RMSE": 13.958733836679095, "best_checkpoint_updated": false, "classification_accuracy": 0.4186851211072664, "Macro-F1": 0.3697767505328358, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 12, "train_total_loss": 1.2764067189259962, "train_regression_loss": 0.017151324988596818, "train_classification_loss": 1.2592553956942125, "validation_total_loss": 1.3447813391685486, "SM0_RMSE": 15.36233067328107, "SM0_MAE": 10.717394319888218, "SM0_R2": 0.7304469197051866, "SM20_RMSE": 14.339809479134521, "SM20_MAE": 10.12722011565337, "SM20_R2": 0.7643567817919332, "mean_validation_RMSE": 14.851070076207796, "current_best_epoch": 10, "current_best_mean_validation_RMSE": 13.958733836679095, "best_checkpoint_updated": false, "classification_accuracy": 0.39100346020761245, "Macro-F1": 0.33955994431800884, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=13 | mean_RMSE=13.1243 | SM0=13.3476 | SM20=12.9011
# {"epoch": 13, "train_total_loss": 1.1852590062401511, "train_regression_loss": 0.014098753094334494, "train_classification_loss": 1.1711602481928738, "validation_total_loss": 1.2982055723667145, "SM0_RMSE": 13.347605812297624, "SM0_MAE": 9.722115672995887, "SM0_R2": 0.7965129265780566, "SM20_RMSE": 12.901086652475103, "SM20_MAE": 9.438590765824367, "SM20_R2": 0.8092692277034725, "mean_validation_RMSE": 13.124346232386364, "current_best_epoch": 13, "current_best_mean_validation_RMSE": 13.124346232386364, "best_checkpoint_updated": true, "classification_accuracy": 0.42560553633217996, "Macro-F1": 0.3823395914190339, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 14, "train_total_loss": 1.1664558215574785, "train_regression_loss": 0.013873172966255383, "train_classification_loss": 1.1525826481255619, "validation_total_loss": 1.2699097275733948, "SM0_RMSE": 14.382404805070056, "SM0_MAE": 10.123364867532954, "SM0_R2": 0.7637384236165752, "SM20_RMSE": 13.889524925122746, "SM20_MAE": 10.08575523332741, "SM20_R2": 0.7789233038529113, "mean_validation_RMSE": 14.135964865096401, "current_best_epoch": 13, "current_best_mean_validation_RMSE": 13.124346232386364, "best_checkpoint_updated": false, "classification_accuracy": 0.4844290657439446, "Macro-F1": 0.4465383204604012, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=15 | mean_RMSE=12.6079 | SM0=12.8357 | SM20=12.3800
# {"epoch": 15, "train_total_loss": 1.0454957431012935, "train_regression_loss": 0.011791319808584045, "train_classification_loss": 1.0337044312195345, "validation_total_loss": 1.180369645357132, "SM0_RMSE": 12.835721242780044, "SM0_MAE": 9.110502678217772, "SM0_R2": 0.8118212260520763, "SM20_RMSE": 12.380036104919016, "SM20_MAE": 9.026885119173354, "SM20_R2": 0.8243646197556186, "mean_validation_RMSE": 12.60787867384953, "current_best_epoch": 15, "current_best_mean_validation_RMSE": 12.60787867384953, "best_checkpoint_updated": true, "classification_accuracy": 0.5121107266435986, "Macro-F1": 0.4660490319243878, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 16, "train_total_loss": 1.005060237917033, "train_regression_loss": 0.011392393710345707, "train_classification_loss": 0.9936678490855477, "validation_total_loss": 1.1624807715415955, "SM0_RMSE": 13.261444392484835, "SM0_MAE": 9.256163437473733, "SM0_R2": 0.7991315454942948, "SM20_RMSE": 12.754146127770936, "SM20_MAE": 9.03432057669006, "SM20_R2": 0.8135892474170086, "mean_validation_RMSE": 13.007795260127885, "current_best_epoch": 15, "current_best_mean_validation_RMSE": 12.60787867384953, "best_checkpoint_updated": false, "classification_accuracy": 0.4982698961937716, "Macro-F1": 0.450305067637191, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=17 | mean_RMSE=12.1394 | SM0=12.4412 | SM20=11.8376
# {"epoch": 17, "train_total_loss": 1.0072910013523968, "train_regression_loss": 0.011881133520298383, "train_classification_loss": 0.9954098720442165, "validation_total_loss": 1.097409325838089, "SM0_RMSE": 12.441219077833463, "SM0_MAE": 8.781037031572994, "SM0_R2": 0.8232107081134306, "SM20_RMSE": 11.837616874896465, "SM20_MAE": 8.445097499652718, "SM20_R2": 0.8394180443853418, "mean_validation_RMSE": 12.139417976364964, "current_best_epoch": 17, "current_best_mean_validation_RMSE": 12.139417976364964, "best_checkpoint_updated": true, "classification_accuracy": 0.5536332179930796, "Macro-F1": 0.5193356715904791, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 18, "train_total_loss": 0.9699590070681139, "train_regression_loss": 0.012185808059505442, "train_classification_loss": 0.9577731964263049, "validation_total_loss": 1.160715964436531, "SM0_RMSE": 12.598733795334148, "SM0_MAE": 9.169674609771649, "SM0_R2": 0.8187058125545575, "SM20_RMSE": 12.737479495223061, "SM20_MAE": 9.400591118525469, "SM20_R2": 0.8140761180448618, "mean_validation_RMSE": 12.668106645278606, "current_best_epoch": 17, "current_best_mean_validation_RMSE": 12.139417976364964, "best_checkpoint_updated": false, "classification_accuracy": 0.5190311418685121, "Macro-F1": 0.4679427559185162, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 19, "train_total_loss": 0.9395134421912107, "train_regression_loss": 0.011560916223309257, "train_classification_loss": 0.9279525225812738, "validation_total_loss": 1.1060812532901765, "SM0_RMSE": 12.797257863017293, "SM0_MAE": 9.105611650898382, "SM0_R2": 0.8129473251416793, "SM20_RMSE": 12.065804304757442, "SM20_MAE": 8.702278395012588, "SM20_R2": 0.8331674694886169, "mean_validation_RMSE": 12.431531083887368, "current_best_epoch": 17, "current_best_mean_validation_RMSE": 12.139417976364964, "best_checkpoint_updated": false, "classification_accuracy": 0.5743944636678201, "Macro-F1": 0.5403269698007305, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 20, "train_total_loss": 0.8735986216501757, "train_regression_loss": 0.01024325842842121, "train_classification_loss": 0.8633553616025231, "validation_total_loss": 1.103524312376976, "SM0_RMSE": 12.548631627087085, "SM0_MAE": 9.077559517432249, "SM0_R2": 0.8201448731938722, "SM20_RMSE": 11.883167709434746, "SM20_MAE": 8.818215626746312, "SM20_R2": 0.8381798364856459, "mean_validation_RMSE": 12.215899668260915, "current_best_epoch": 17, "current_best_mean_validation_RMSE": 12.139417976364964, "best_checkpoint_updated": false, "classification_accuracy": 0.5224913494809689, "Macro-F1": 0.48311679133158913, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=21 | mean_RMSE=11.6278 | SM0=11.8010 | SM20=11.4546
# {"epoch": 21, "train_total_loss": 0.8645597547292709, "train_regression_loss": 0.010879757486029783, "train_classification_loss": 0.8536799983544783, "validation_total_loss": 1.0629534989595413, "SM0_RMSE": 11.800986630710515, "SM0_MAE": 8.591981469141158, "SM0_R2": 0.8409378978738953, "SM20_RMSE": 11.454634909385637, "SM20_MAE": 8.124978894284027, "SM20_R2": 0.8496405647063026, "mean_validation_RMSE": 11.627810770048075, "current_best_epoch": 21, "current_best_mean_validation_RMSE": 11.627810770048075, "best_checkpoint_updated": true, "classification_accuracy": 0.5778546712802768, "Macro-F1": 0.547761082894539, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 22, "train_total_loss": 0.830384609374133, "train_regression_loss": 0.01009421331003647, "train_classification_loss": 0.8202903934500434, "validation_total_loss": 1.0293392926454543, "SM0_RMSE": 12.216118737793607, "SM0_MAE": 9.03959905039068, "SM0_R2": 0.8295501703223574, "SM20_RMSE": 11.879248165579346, "SM20_MAE": 8.64497232127767, "SM20_R2": 0.8382865684010293, "mean_validation_RMSE": 12.047683451686478, "current_best_epoch": 21, "current_best_mean_validation_RMSE": 11.627810770048075, "best_checkpoint_updated": false, "classification_accuracy": 0.6089965397923875, "Macro-F1": 0.5759020801133172, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=23 | mean_RMSE=11.4740 | SM0=11.5764 | SM20=11.3715
# {"epoch": 23, "train_total_loss": 0.8005754283883355, "train_regression_loss": 0.008771635237446224, "train_classification_loss": 0.7918037907643751, "validation_total_loss": 1.021630023419857, "SM0_RMSE": 11.57641491118471, "SM0_MAE": 8.594191928223342, "SM0_R2": 0.8469341706611841, "SM20_RMSE": 11.371512633766855, "SM20_MAE": 8.310188653972322, "SM20_R2": 0.8518148585049187, "mean_validation_RMSE": 11.473963772475782, "current_best_epoch": 23, "current_best_mean_validation_RMSE": 11.473963772475782, "best_checkpoint_updated": true, "classification_accuracy": 0.5813148788927336, "Macro-F1": 0.545391289986729, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=24 | mean_RMSE=11.2796 | SM0=11.3998 | SM20=11.1594
# {"epoch": 24, "train_total_loss": 0.7708317149769176, "train_regression_loss": 0.009529167638075623, "train_classification_loss": 0.7613025510852988, "validation_total_loss": 0.9963503450155258, "SM0_RMSE": 11.399786003343392, "SM0_MAE": 8.368110140199068, "SM0_R2": 0.8515693878117472, "SM20_RMSE": 11.159407748873093, "SM20_MAE": 8.14237574504682, "SM20_R2": 0.8572912916006548, "mean_validation_RMSE": 11.279596876108243, "current_best_epoch": 24, "current_best_mean_validation_RMSE": 11.279596876108243, "best_checkpoint_updated": true, "classification_accuracy": 0.6020761245674741, "Macro-F1": 0.5683082460959398, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=25 | mean_RMSE=10.8735 | SM0=11.0148 | SM20=10.7322
# {"epoch": 25, "train_total_loss": 0.7847081422805786, "train_regression_loss": 0.009963497530076314, "train_classification_loss": 0.7747446474703875, "validation_total_loss": 0.9902065426111222, "SM0_RMSE": 11.014774529669857, "SM0_MAE": 8.110301765397345, "SM0_R2": 0.8614261432555803, "SM20_RMSE": 10.7322121446389, "SM20_MAE": 7.816648746238036, "SM20_R2": 0.8680082823748586, "mean_validation_RMSE": 10.873493337154379, "current_best_epoch": 25, "current_best_mean_validation_RMSE": 10.873493337154379, "best_checkpoint_updated": true, "classification_accuracy": 0.5986159169550173, "Macro-F1": 0.5683933255569882, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 26, "train_total_loss": 0.8046251846985384, "train_regression_loss": 0.00997417081486095, "train_classification_loss": 0.7946510098197244, "validation_total_loss": 0.9530751310288906, "SM0_RMSE": 11.161792548961431, "SM0_MAE": 8.058359743298956, "SM0_R2": 0.8577022693504349, "SM20_RMSE": 10.820816261668355, "SM20_MAE": 7.960386029783005, "SM20_R2": 0.8658198638312328, "mean_validation_RMSE": 10.991304405314892, "current_best_epoch": 25, "current_best_mean_validation_RMSE": 10.873493337154379, "best_checkpoint_updated": false, "classification_accuracy": 0.6124567474048442, "Macro-F1": 0.568048511229746, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 27, "train_total_loss": 0.6918211626735601, "train_regression_loss": 0.0074430060922168195, "train_classification_loss": 0.6843781566078012, "validation_total_loss": 0.9788366243243217, "SM0_RMSE": 11.858888262883642, "SM0_MAE": 8.294022570947462, "SM0_R2": 0.8393731897732197, "SM20_RMSE": 11.34625437944847, "SM20_MAE": 8.195909748027894, "SM20_R2": 0.8524724211832716, "mean_validation_RMSE": 11.602571321166057, "current_best_epoch": 25, "current_best_mean_validation_RMSE": 10.873493337154379, "best_checkpoint_updated": false, "classification_accuracy": 0.6089965397923875, "Macro-F1": 0.5730329670315573, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 28, "train_total_loss": 0.7430551092733036, "train_regression_loss": 0.00910298945911398, "train_classification_loss": 0.7339521185918287, "validation_total_loss": 0.9451461218297481, "SM0_RMSE": 11.179011792740637, "SM0_MAE": 7.936069938138282, "SM0_R2": 0.857262886643013, "SM20_RMSE": 10.609420610237533, "SM20_MAE": 7.746971069322738, "SM20_R2": 0.8710113440490792, "mean_validation_RMSE": 10.894216201489085, "current_best_epoch": 25, "current_best_mean_validation_RMSE": 10.873493337154379, "best_checkpoint_updated": false, "classification_accuracy": 0.6055363321799307, "Macro-F1": 0.5695287480285627, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=29 | mean_RMSE=10.6692 | SM0=10.9228 | SM20=10.4155
# {"epoch": 29, "train_total_loss": 0.6418197243051096, "train_regression_loss": 0.007688692897896875, "train_classification_loss": 0.6341310292482376, "validation_total_loss": 0.9426357470452785, "SM0_RMSE": 10.922834198513685, "SM0_MAE": 7.785625590585095, "SM0_R2": 0.863729840649177, "SM20_RMSE": 10.415476142543866, "SM20_MAE": 7.6539126836717335, "SM20_R2": 0.8756841683344635, "mean_validation_RMSE": 10.669155170528775, "current_best_epoch": 29, "current_best_mean_validation_RMSE": 10.669155170528775, "best_checkpoint_updated": true, "classification_accuracy": 0.6262975778546713, "Macro-F1": 0.5903579113035554, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 30, "train_total_loss": 0.6471912528980862, "train_regression_loss": 0.00806736163477498, "train_classification_loss": 0.6391238942742348, "validation_total_loss": 0.9514624886214733, "SM0_RMSE": 11.345988587267529, "SM0_MAE": 8.080671083968403, "SM0_R2": 0.8529670178585238, "SM20_RMSE": 10.81758919708926, "SM20_MAE": 7.975792705703359, "SM20_R2": 0.8658998843004369, "mean_validation_RMSE": 11.081788892178395, "current_best_epoch": 29, "current_best_mean_validation_RMSE": 10.669155170528775, "best_checkpoint_updated": false, "classification_accuracy": 0.615916955017301, "Macro-F1": 0.5740109666630671, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 31, "train_total_loss": 0.6333785856311972, "train_regression_loss": 0.007089878659991717, "train_classification_loss": 0.6262887045741081, "validation_total_loss": 0.9898657977581025, "SM0_RMSE": 11.986396684606659, "SM0_MAE": 8.227411101021156, "SM0_R2": 0.8359004561839605, "SM20_RMSE": 11.282351487670155, "SM20_MAE": 7.906380899637216, "SM20_R2": 0.8541295126945491, "mean_validation_RMSE": 11.634374086138408, "current_best_epoch": 29, "current_best_mean_validation_RMSE": 10.669155170528775, "best_checkpoint_updated": false, "classification_accuracy": 0.6193771626297578, "Macro-F1": 0.5771934456601516, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=32 | mean_RMSE=10.3646 | SM0=10.3917 | SM20=10.3374
# {"epoch": 32, "train_total_loss": 0.5836892290548845, "train_regression_loss": 0.006856159640433775, "train_classification_loss": 0.5768330727111209, "validation_total_loss": 0.9467316206544638, "SM0_RMSE": 10.391689519976882, "SM0_MAE": 7.550114562354699, "SM0_R2": 0.8766604368083021, "SM20_RMSE": 10.337413672022967, "SM20_MAE": 7.4090672614871425, "SM20_R2": 0.8775406431186034, "mean_validation_RMSE": 10.364551595999924, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": true, "classification_accuracy": 0.6228373702422145, "Macro-F1": 0.5870784720811197, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 33, "train_total_loss": 0.5814652984792535, "train_regression_loss": 0.007514961778228594, "train_classification_loss": 0.5739503380927172, "validation_total_loss": 0.9203217118978501, "SM0_RMSE": 10.942217187494885, "SM0_MAE": 7.975529820758166, "SM0_R2": 0.8632457782687196, "SM20_RMSE": 10.577760646281192, "SM20_MAE": 7.682092783772822, "SM20_R2": 0.8717800350218067, "mean_validation_RMSE": 10.759988916888037, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": false, "classification_accuracy": 0.615916955017301, "Macro-F1": 0.5761109123747207, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 34, "train_total_loss": 0.6253005841916258, "train_regression_loss": 0.0072510669759305365, "train_classification_loss": 0.6180495152419264, "validation_total_loss": 1.0023614004254342, "SM0_RMSE": 11.847824659902637, "SM0_MAE": 8.851353981296908, "SM0_R2": 0.8396727595558344, "SM20_RMSE": 11.661535210945797, "SM20_MAE": 8.26625917857081, "SM20_R2": 0.8441597491349146, "mean_validation_RMSE": 11.754679935424218, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": false, "classification_accuracy": 0.5986159169550173, "Macro-F1": 0.5665058676807068, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 35, "train_total_loss": 0.574900240383365, "train_regression_loss": 0.006611696010540155, "train_classification_loss": 0.5682885443622415, "validation_total_loss": 0.9539965584874153, "SM0_RMSE": 11.097657553934267, "SM0_MAE": 8.158056522838796, "SM0_R2": 0.8593328398385232, "SM20_RMSE": 11.29716087377314, "SM20_MAE": 8.135021162486819, "SM20_R2": 0.8537463177267357, "mean_validation_RMSE": 11.197409213853703, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": false, "classification_accuracy": 0.6228373702422145, "Macro-F1": 0.584323511329156, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 36, "train_total_loss": 0.5175422843207013, "train_regression_loss": 0.006137483737389134, "train_classification_loss": 0.5114047981121324, "validation_total_loss": 0.953320124745369, "SM0_RMSE": 10.77354606586841, "SM0_MAE": 7.789401377361126, "SM0_R2": 0.8674293374039794, "SM20_RMSE": 10.739109056098926, "SM20_MAE": 7.6111232446551735, "SM20_R2": 0.8678385824686391, "mean_validation_RMSE": 10.756327560983667, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": false, "classification_accuracy": 0.6401384083044983, "Macro-F1": 0.6216339967613276, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 37, "train_total_loss": 0.5516045154495672, "train_regression_loss": 0.006890834774821997, "train_classification_loss": 0.544713678007776, "validation_total_loss": 1.0254849798977375, "SM0_RMSE": 12.112086071572188, "SM0_MAE": 8.645920409772636, "SM0_R2": 0.8324409159225856, "SM20_RMSE": 12.007318790328043, "SM20_MAE": 8.493888795298483, "SM20_R2": 0.8347808950515807, "mean_validation_RMSE": 12.059702430950114, "current_best_epoch": 32, "current_best_mean_validation_RMSE": 10.364551595999924, "best_checkpoint_updated": false, "classification_accuracy": 0.643598615916955, "Macro-F1": 0.622232000122629, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=38 | mean_RMSE=10.3342 | SM0=10.5677 | SM20=10.1006
# {"epoch": 38, "train_total_loss": 0.5594381500374187, "train_regression_loss": 0.007546057818796147, "train_classification_loss": 0.5518920909274708, "validation_total_loss": 0.9221392832696438, "SM0_RMSE": 10.567709638721427, "SM0_MAE": 7.6952880299215085, "SM0_R2": 0.8724466630012575, "SM20_RMSE": 10.100620583287855, "SM20_MAE": 7.406618252757512, "SM20_R2": 0.8830865979478454, "mean_validation_RMSE": 10.33416511100464, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": true, "classification_accuracy": 0.6332179930795848, "Macro-F1": 0.6017823527713302, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 39, "train_total_loss": 0.5169877829876813, "train_regression_loss": 0.006499001396481286, "train_classification_loss": 0.510488781739365, "validation_total_loss": 0.9524622015655041, "SM0_RMSE": 10.613146706814927, "SM0_MAE": 7.710409512981824, "SM0_R2": 0.8713474448386893, "SM20_RMSE": 10.56778276952934, "SM20_MAE": 7.6427558392389425, "SM20_R2": 0.8720218176913961, "mean_validation_RMSE": 10.590464738172134, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.6332179930795848, "Macro-F1": 0.5961072982046401, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 40, "train_total_loss": 0.5152706368403002, "train_regression_loss": 0.0065757285708307545, "train_classification_loss": 0.5086949061263691, "validation_total_loss": 0.9596394903957843, "SM0_RMSE": 11.299182637173653, "SM0_MAE": 7.973087472486661, "SM0_R2": 0.8541776348218677, "SM20_RMSE": 11.369947551140683, "SM20_MAE": 8.10149570237394, "SM20_R2": 0.851855645696201, "mean_validation_RMSE": 11.334565094157167, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.6366782006920415, "Macro-F1": 0.6074027400568942, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 41, "train_total_loss": 0.5272520753470334, "train_regression_loss": 0.006529473948334767, "train_classification_loss": 0.5207226019014012, "validation_total_loss": 0.9485213037580251, "SM0_RMSE": 10.73332208135333, "SM0_MAE": 7.904483371746169, "SM0_R2": 0.8684174179355827, "SM20_RMSE": 11.07633234955943, "SM20_MAE": 8.106004727340487, "SM20_R2": 0.8594081519554665, "mean_validation_RMSE": 10.904827215456379, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.6470588235294118, "Macro-F1": 0.6194795802868951, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 42, "train_total_loss": 0.5093129399147901, "train_regression_loss": 0.006589639582671225, "train_classification_loss": 0.5027233009988611, "validation_total_loss": 0.96422283295542, "SM0_RMSE": 11.072620089471402, "SM0_MAE": 8.104971561980495, "SM0_R2": 0.8599668431974685, "SM20_RMSE": 11.113084625241996, "SM20_MAE": 7.927205501543197, "SM20_R2": 0.8584736110625353, "mean_validation_RMSE": 11.092852357356698, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.629757785467128, "Macro-F1": 0.5979382155266741, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 43, "train_total_loss": 0.5269072706049139, "train_regression_loss": 0.006446456314403225, "train_classification_loss": 0.5204608135602691, "validation_total_loss": 0.9699748784303666, "SM0_RMSE": 10.990644164332862, "SM0_MAE": 8.061150084729839, "SM0_R2": 0.8620326332136504, "SM20_RMSE": 11.019705510686743, "SM20_MAE": 8.179133538143857, "SM20_R2": 0.860842005870498, "mean_validation_RMSE": 11.005174837509802, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.6401384083044983, "Macro-F1": 0.6089880895245983, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 44, "train_total_loss": 0.4973544739186764, "train_regression_loss": 0.006727054019310427, "train_classification_loss": 0.4906274208968336, "validation_total_loss": 0.9165962586179376, "SM0_RMSE": 10.422313795130583, "SM0_MAE": 7.5874844777130335, "SM0_R2": 0.875932403048483, "SM20_RMSE": 10.704504525822294, "SM20_MAE": 7.818087434067445, "SM20_R2": 0.8686889352054848, "mean_validation_RMSE": 10.56340916047644, "current_best_epoch": 38, "current_best_mean_validation_RMSE": 10.33416511100464, "best_checkpoint_updated": false, "classification_accuracy": 0.6816608996539792, "Macro-F1": 0.6470998391922805, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=45 | mean_RMSE=10.0725 | SM0=10.0042 | SM20=10.1408
# {"epoch": 45, "train_total_loss": 0.47259697114879434, "train_regression_loss": 0.005901731645942412, "train_classification_loss": 0.46669523553414777, "validation_total_loss": 0.907998188585043, "SM0_RMSE": 10.004201273027945, "SM0_MAE": 7.2103275576264805, "SM0_R2": 0.8856871842842379, "SM20_RMSE": 10.140796607055027, "SM20_MAE": 7.450157015381388, "SM20_R2": 0.8821546834864128, "mean_validation_RMSE": 10.072498940041486, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": true, "classification_accuracy": 0.657439446366782, "Macro-F1": 0.6334495357154961, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 46, "train_total_loss": 0.4811214530332522, "train_regression_loss": 0.0059457953162068, "train_classification_loss": 0.47517565536228096, "validation_total_loss": 0.915819283016026, "SM0_RMSE": 9.939594947716461, "SM0_MAE": 7.239175678949455, "SM0_R2": 0.8871588627965995, "SM20_RMSE": 10.31851635106759, "SM20_MAE": 7.618353857713587, "SM20_R2": 0.8779879578239251, "mean_validation_RMSE": 10.129055649392026, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6539792387543253, "Macro-F1": 0.6188368626163752, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 47, "train_total_loss": 0.4613461836495183, "train_regression_loss": 0.006388978831554678, "train_classification_loss": 0.45495720546353946, "validation_total_loss": 1.0064495600759984, "SM0_RMSE": 11.396300932626088, "SM0_MAE": 8.463438172653884, "SM0_R2": 0.8516601284815173, "SM20_RMSE": 11.447102691687526, "SM20_MAE": 8.432833264855777, "SM20_R2": 0.8498382432262581, "mean_validation_RMSE": 11.421701812156808, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.5882352941176471, "Macro-F1": 0.5488929262956722, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 48, "train_total_loss": 0.43704283372922376, "train_regression_loss": 0.005836338228122754, "train_classification_loss": 0.4312064911831509, "validation_total_loss": 0.9442800436168909, "SM0_RMSE": 10.94563806627467, "SM0_MAE": 7.841909548815559, "SM0_R2": 0.8631602576224631, "SM20_RMSE": 11.045896134577648, "SM20_MAE": 7.780006748994741, "SM20_R2": 0.8601797439255487, "mean_validation_RMSE": 10.995767100426159, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6539792387543253, "Macro-F1": 0.6273222258979886, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 49, "train_total_loss": 0.45838985219597816, "train_regression_loss": 0.005704251721247353, "train_classification_loss": 0.45268560302528466, "validation_total_loss": 0.9862613797187805, "SM0_RMSE": 10.458436432729103, "SM0_MAE": 7.760567285197829, "SM0_R2": 0.8750709023508155, "SM20_RMSE": 10.69393326521593, "SM20_MAE": 7.773362337924205, "SM20_R2": 0.8689481602935138, "mean_validation_RMSE": 10.576184848972517, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6332179930795848, "Macro-F1": 0.5927521591871568, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 50, "train_total_loss": 0.45997433296658774, "train_regression_loss": 0.006477206014096737, "train_classification_loss": 0.4534971246665174, "validation_total_loss": 0.9341042129322886, "SM0_RMSE": 10.473645818164599, "SM0_MAE": 7.423429340227252, "SM0_R2": 0.874707276978042, "SM20_RMSE": 10.40463191404071, "SM20_MAE": 7.3933685203840165, "SM20_R2": 0.8759429001417559, "mean_validation_RMSE": 10.439138866102654, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.671280276816609, "Macro-F1": 0.6446964264322281, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 51, "train_total_loss": 0.4397584514861757, "train_regression_loss": 0.006499571434687823, "train_classification_loss": 0.43325888230042026, "validation_total_loss": 0.9764576273038983, "SM0_RMSE": 10.481278238567041, "SM0_MAE": 7.844473380634116, "SM0_R2": 0.8745246022556594, "SM20_RMSE": 10.42682811143709, "SM20_MAE": 7.733267609429607, "SM20_R2": 0.8754130336318822, "mean_validation_RMSE": 10.454053175002066, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6228373702422145, "Macro-F1": 0.5828354090544876, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 52, "train_total_loss": 0.4181721650741317, "train_regression_loss": 0.005217960884858092, "train_classification_loss": 0.41295420480045403, "validation_total_loss": 0.9251634117215872, "SM0_RMSE": 10.265658746976149, "SM0_MAE": 7.262103597185604, "SM0_R2": 0.8796340279368089, "SM20_RMSE": 10.318594714873473, "SM20_MAE": 7.1272274464059455, "SM20_R2": 0.877986104579918, "mean_validation_RMSE": 10.29212673092481, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6608996539792388, "Macro-F1": 0.6198208258099418, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 53, "train_total_loss": 0.41297087784517894, "train_regression_loss": 0.004954804343552413, "train_classification_loss": 0.40801607444882393, "validation_total_loss": 0.9514306589961052, "SM0_RMSE": 10.41387707837748, "SM0_MAE": 7.626029382939982, "SM0_R2": 0.8761331837082145, "SM20_RMSE": 10.616443048335423, "SM20_MAE": 7.7209462620395275, "SM20_R2": 0.8708405308318206, "mean_validation_RMSE": 10.51516006335645, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6470588235294118, "Macro-F1": 0.6100426513852826, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 54, "train_total_loss": 0.4100117033178156, "train_regression_loss": 0.0057332928144288335, "train_classification_loss": 0.404278406704014, "validation_total_loss": 0.9690700633451342, "SM0_RMSE": 10.026838017152171, "SM0_MAE": 7.402647957876066, "SM0_R2": 0.8851692823588461, "SM20_RMSE": 10.238293470791861, "SM20_MAE": 7.486933661992162, "SM20_R2": 0.8798777852677024, "mean_validation_RMSE": 10.132565743972016, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6643598615916955, "Macro-F1": 0.6333215039640762, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 55, "train_total_loss": 0.43910387124527583, "train_regression_loss": 0.005650829920672219, "train_classification_loss": 0.43345304239879956, "validation_total_loss": 0.9716036656871438, "SM0_RMSE": 10.125712627286662, "SM0_MAE": 7.354530463787924, "SM0_R2": 0.8828934257993877, "SM20_RMSE": 10.483195196744042, "SM20_MAE": 7.582567058632531, "SM20_R2": 0.8740623666662074, "mean_validation_RMSE": 10.30445391201535, "current_best_epoch": 45, "current_best_mean_validation_RMSE": 10.072498940041486, "best_checkpoint_updated": false, "classification_accuracy": 0.6678200692041523, "Macro-F1": 0.6295729501450139, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=56 | mean_RMSE=9.9180 | SM0=9.7703 | SM20=10.0656
# {"epoch": 56, "train_total_loss": 0.3708759783343835, "train_regression_loss": 0.005504051091107117, "train_classification_loss": 0.3653719269416549, "validation_total_loss": 0.9333063470199704, "SM0_RMSE": 9.770296827977543, "SM0_MAE": 7.096588325851104, "SM0_R2": 0.8909701041789103, "SM20_RMSE": 10.065614018581323, "SM20_MAE": 7.261867628378027, "SM20_R2": 0.8838955867165561, "mean_validation_RMSE": 9.917955423279434, "current_best_epoch": 56, "current_best_mean_validation_RMSE": 9.917955423279434, "best_checkpoint_updated": true, "classification_accuracy": 0.657439446366782, "Macro-F1": 0.6300565686314907, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 57, "train_total_loss": 0.37123090045695956, "train_regression_loss": 0.004711419058201665, "train_classification_loss": 0.36651948145167396, "validation_total_loss": 1.0037699423730373, "SM0_RMSE": 10.86060010793592, "SM0_MAE": 7.833600080446389, "SM0_R2": 0.865278246411613, "SM20_RMSE": 10.964884940174313, "SM20_MAE": 7.8630581720632255, "SM20_R2": 0.8622231217329187, "mean_validation_RMSE": 10.912742524055115, "current_best_epoch": 56, "current_best_mean_validation_RMSE": 9.917955423279434, "best_checkpoint_updated": false, "classification_accuracy": 0.6608996539792388, "Macro-F1": 0.6220211497966237, "regression_metric_scale": "original_0_to_100_percentage_points"}
# BEST REGRESSION UPDATED | epoch=58 | mean_RMSE=9.8522 | SM0=9.8496 | SM20=9.8549
# {"epoch": 58, "train_total_loss": 0.353599281812256, "train_regression_loss": 0.0043713554623536766, "train_classification_loss": 0.3492279245772145, "validation_total_loss": 0.9665791009552777, "SM0_RMSE": 9.849564062455903, "SM0_MAE": 7.084054287742166, "SM0_R2": 0.8891937902909189, "SM20_RMSE": 9.854931200572386, "SM20_MAE": 7.075375991090358, "SM20_R2": 0.8887050711366011, "mean_validation_RMSE": 9.852247631514144, "current_best_epoch": 58, "current_best_mean_validation_RMSE": 9.852247631514144, "best_checkpoint_updated": true, "classification_accuracy": 0.6678200692041523, "Macro-F1": 0.6371890840809461, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 59, "train_total_loss": 0.3608132316307588, "train_regression_loss": 0.0047411108548244965, "train_classification_loss": 0.3560721213844689, "validation_total_loss": 0.9416054055094719, "SM0_RMSE": 10.225374729305967, "SM0_MAE": 7.188870359044587, "SM0_R2": 0.8805768434538225, "SM20_RMSE": 10.46523208507864, "SM20_MAE": 7.5305087285883285, "SM20_R2": 0.8744935889308041, "mean_validation_RMSE": 10.345303407192304, "current_best_epoch": 58, "current_best_mean_validation_RMSE": 9.852247631514144, "best_checkpoint_updated": false, "classification_accuracy": 0.657439446366782, "Macro-F1": 0.6264082858524561, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {"epoch": 60, "train_total_loss": 0.3526408188045025, "train_regression_loss": 0.00476578743705018, "train_classification_loss": 0.3478750308806246, "validation_total_loss": 0.9682620069943368, "SM0_RMSE": 9.822311856962008, "SM0_MAE": 7.113829173018775, "SM0_R2": 0.8898061089762763, "SM20_RMSE": 10.009316556700028, "SM20_MAE": 7.1506702854559085, "SM20_R2": 0.8851907098188485, "mean_validation_RMSE": 9.915814206831019, "current_best_epoch": 58, "current_best_mean_validation_RMSE": 9.852247631514144, "best_checkpoint_updated": false, "classification_accuracy": 0.671280276816609, "Macro-F1": 0.6284469603006192, "regression_metric_scale": "original_0_to_100_percentage_points"}
# {'SUPERVISED_ACTION': 'TRAINED_OR_RESUMED_TO_60_EPOCHS', 'epochs_completed': 60, 'best_epoch': 58, 'best_mean_validation_RMSE': 9.852247631514144, 'best_checkpoint': 'release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_best_regression.pth', 'best_checkpoint_sha256': 'e2119a5b7a289925584fba8d3cd57040b7835461fc39d686bda464227de50020', 'TEST_LOADER_INSTANTIATED': False}

# %% [markdown]
# ## 10. Validation history and best-checkpoint selection audit

# %%
history = pd.read_csv(supervised_dir / "training_history.csv")
if len(history) != 60 or history["epoch"].tolist() != list(range(1, 61)):
    raise RuntimeError("STOP: supervised history is not exactly 60 sequential epochs")
minimum_index = history["mean_regression_RMSE"].idxmin()
minimum_row = history.loc[minimum_index]
if int(minimum_row["epoch"]) != int(run_metadata["best_epoch"]):
    raise RuntimeError("STOP: saved best epoch is not the strict minimum validation mean RMSE")
display(history[[
    "epoch", "total_loss", "regression_loss", "classification_loss",
    "validation_SM_0_rmse", "validation_SM_0_mae", "validation_SM_0_r2",
    "validation_SM_20_rmse", "validation_SM_20_mae", "validation_SM_20_r2",
    "mean_regression_RMSE", "is_best_regression",
]])
print({
    "best_epoch": int(minimum_row["epoch"]),
    "minimum_validation_mean_RMSE": float(minimum_row["mean_regression_RMSE"]),
    "selection_formula": context.config["selection_formula"],
    "early_stopping_used": False,
})
# Out:
#     epoch  total_loss  regression_loss  classification_loss  \
# 0       1    2.578171         0.294644             2.283527
# 1       2    2.321083         0.101944             2.219139
# 2       3    2.190561         0.055971             2.134590
# 3       4    2.075313         0.039753             2.035560
# 4       5    1.936608         0.030958             1.905651
# 5       6    1.802105         0.025674             1.776431
# 6       7    1.674587         0.024222             1.650365
# 7       8    1.585741         0.022943             1.562798
# 8       9    1.457885         0.019074             1.438811
# 9      10    1.374924         0.017323             1.357601
# 10     11    1.327836         0.016515             1.311322
# 11     12    1.276407         0.017151             1.259255
# 12     13    1.185259         0.014099             1.171160
# 13     14    1.166456         0.013873             1.152583
# 14     15    1.045496         0.011791             1.033704
# 15     16    1.005060         0.011392             0.993668
# 16     17    1.007291         0.011881             0.995410
# 17     18    0.969959         0.012186             0.957773
# 18     19    0.939513         0.011561             0.927953
# 19     20    0.873599         0.010243             0.863355
# 20     21    0.864560         0.010880             0.853680
# 21     22    0.830385         0.010094             0.820290
# 22     23    0.800575         0.008772             0.791804
# 23     24    0.770832         0.009529             0.761303
# 24     25    0.784708         0.009963             0.774745
# 25     26    0.804625         0.009974             0.794651
# 26     27    0.691821         0.007443             0.684378
# 27     28    0.743055         0.009103             0.733952
# 28     29    0.641820         0.007689             0.634131
# 29     30    0.647191         0.008067             0.639124
# 30     31    0.633379         0.007090             0.626289
# 31     32    0.583689         0.006856             0.576833
# 32     33    0.581465         0.007515             0.573950
# 33     34    0.625301         0.007251             0.618050
# 34     35    0.574900         0.006612             0.568289
# 35     36    0.517542         0.006137             0.511405
# 36     37    0.551605         0.006891             0.544714
# 37     38    0.559438         0.007546             0.551892
# 38     39    0.516988         0.006499             0.510489
# 39     40    0.515271         0.006576             0.508695
# 40     41    0.527252         0.006529             0.520723
# 41     42    0.509313         0.006590             0.502723
# 42     43    0.526907         0.006446             0.520461
# 43     44    0.497354         0.006727             0.490627
# 44     45    0.472597         0.005902             0.466695
# 45     46    0.481121         0.005946             0.475176
# 46     47    0.461346         0.006389             0.454957
# 47     48    0.437043         0.005836             0.431206
# 48     49    0.458390         0.005704             0.452686
# 49     50    0.459974         0.006477             0.453497
# 50     51    0.439758         0.006500             0.433259
# 51     52    0.418172         0.005218             0.412954
# 52     53    0.412971         0.004955             0.408016
# 53     54    0.410012         0.005733             0.404278
# 54     55    0.439104         0.005651             0.433453
# 55     56    0.370876         0.005504             0.365372
# 56     57    0.371231         0.004711             0.366519
# 57     58    0.353599         0.004371             0.349228
# 58     59    0.360813         0.004741             0.356072
# 59     60    0.352641         0.004766             0.347875
#
#     validation_SM_0_rmse  validation_SM_0_mae  validation_SM_0_r2  \
# 0              37.218725            29.010958           -0.582170
# 1              23.781516            18.706343            0.354035
# 2              19.753100            15.268697            0.554343
# 3              17.744807            13.736214            0.640356
# 4              16.459055            12.699694            0.690586
# 5              16.301181            12.116648            0.696493
# 6              15.941885            11.845375            0.709725
# 7              16.078708            11.278510            0.704721
# 8              14.347423            10.567128            0.764886
# 9              14.188027            10.477837            0.770081
# 10             14.207805            10.367084            0.769440
# 11             15.362331            10.717394            0.730447
# 12             13.347606             9.722116            0.796513
# 13             14.382405            10.123365            0.763738
# 14             12.835721             9.110503            0.811821
# 15             13.261444             9.256163            0.799132
# 16             12.441219             8.781037            0.823211
# 17             12.598734             9.169675            0.818706
# 18             12.797258             9.105612            0.812947
# 19             12.548632             9.077560            0.820145
# 20             11.800987             8.591981            0.840938
# 21             12.216119             9.039599            0.829550
# 22             11.576415             8.594192            0.846934
# 23             11.399786             8.368110            0.851569
# 24             11.014775             8.110302            0.861426
# 25             11.161793             8.058360            0.857702
# 26             11.858888             8.294023            0.839373
# 27             11.179012             7.936070            0.857263
# 28             10.922834             7.785626            0.863730
# 29             11.345989             8.080671            0.852967
# 30             11.986397             8.227411            0.835900
# 31             10.391690             7.550115            0.876660
# 32             10.942217             7.975530            0.863246
# 33             11.847825             8.851354            0.839673
# 34             11.097658             8.158057            0.859333
# 35             10.773546             7.789401            0.867429
# 36             12.112086             8.645920            0.832441
# 37             10.567710             7.695288            0.872447
# 38             10.613147             7.710410            0.871347
# 39             11.299183             7.973087            0.854178
# 40             10.733322             7.904483            0.868417
# 41             11.072620             8.104972            0.859967
# 42             10.990644             8.061150            0.862033
# 43             10.422314             7.587484            0.875932
# 44             10.004201             7.210328            0.885687
# 45              9.939595             7.239176            0.887159
# 46             11.396301             8.463438            0.851660
# 47             10.945638             7.841910            0.863160
# 48             10.458436             7.760567            0.875071
# 49             10.473646             7.423429            0.874707
# 50             10.481278             7.844473            0.874525
# 51             10.265659             7.262104            0.879634
# 52             10.413877             7.626029            0.876133
# 53             10.026838             7.402648            0.885169
# 54             10.125713             7.354530            0.882893
# 55              9.770297             7.096588            0.890970
# 56             10.860600             7.833600            0.865278
# 57              9.849564             7.084054            0.889194
# 58             10.225375             7.188870            0.880577
# 59              9.822312             7.113829            0.889806
#
#     validation_SM_20_rmse  validation_SM_20_mae  validation_SM_20_r2  \
# 0               32.327734             24.809040            -0.197619
# 1               22.375343             17.905383             0.426270
# 2               18.793652             14.495649             0.595247
# 3               17.609665             13.542994             0.644638
# 4               16.436248             12.559463             0.690420
# 5               15.853798             11.855303             0.711972
# 6               15.356695             11.829642             0.729751
# 7               15.339790             11.084587             0.730346
# 8               14.210241             10.761626             0.768596
# 9               13.729440             10.171439             0.783990
# 10              13.769103             10.088661             0.782740
# 11              14.339809             10.127220             0.764357
# 12              12.901087              9.438591             0.809269
# 13              13.889525             10.085755             0.778923
# 14              12.380036              9.026885             0.824365
# 15              12.754146              9.034321             0.813589
# 16              11.837617              8.445097             0.839418
# 17              12.737479              9.400591             0.814076
# 18              12.065804              8.702278             0.833167
# 19              11.883168              8.818216             0.838180
# 20              11.454635              8.124979             0.849641
# 21              11.879248              8.644972             0.838287
# 22              11.371513              8.310189             0.851815
# 23              11.159408              8.142376             0.857291
# 24              10.732212              7.816649             0.868008
# 25              10.820816              7.960386             0.865820
# 26              11.346254              8.195910             0.852472
# 27              10.609421              7.746971             0.871011
# 28              10.415476              7.653913             0.875684
# 29              10.817589              7.975793             0.865900
# 30              11.282351              7.906381             0.854130
# 31              10.337414              7.409067             0.877541
# 32              10.577761              7.682093             0.871780
# 33              11.661535              8.266259             0.844160
# 34              11.297161              8.135021             0.853746
# 35              10.739109              7.611123             0.867839
# 36              12.007319              8.493889             0.834781
# 37              10.100621              7.406618             0.883087
# 38              10.567783              7.642756             0.872022
# 39              11.369948              8.101496             0.851856
# 40              11.076332              8.106005             0.859408
# 41              11.113085              7.927206             0.858474
# 42              11.019706              8.179134             0.860842
# 43              10.704505              7.818087             0.868689
# 44              10.140797              7.450157             0.882155
# 45              10.318516              7.618354             0.877988
# 46              11.447103              8.432833             0.849838
# 47              11.045896              7.780007             0.860180
# 48              10.693933              7.773362             0.868948
# 49              10.404632              7.393369             0.875943
# 50              10.426828              7.733268             0.875413
# 51              10.318595              7.127227             0.877986
# 52              10.616443              7.720946             0.870841
# 53              10.238293              7.486934             0.879878
# 54              10.483195              7.582567             0.874062
# 55              10.065614              7.261868             0.883896
# 56              10.964885              7.863058             0.862223
# 57               9.854931              7.075376             0.888705
# 58              10.465232              7.530509             0.874494
# 59              10.009317              7.150670             0.885191
#
#     mean_regression_RMSE  is_best_regression
# 0              34.773229                True
# 1              23.078430                True
# 2              19.273376                True
# 3              17.677236                True
# 4              16.447651                True
# 5              16.077489                True
# 6              15.649290                True
# 7              15.709249               False
# 8              14.278832                True
# 9              13.958734                True
# 10             13.988454               False
# 11             14.851070               False
# 12             13.124346                True
# 13             14.135965               False
# 14             12.607879                True
# 15             13.007795               False
# 16             12.139418                True
# 17             12.668107               False
# 18             12.431531               False
# 19             12.215900               False
# 20             11.627811                True
# 21             12.047683               False
# 22             11.473964                True
# 23             11.279597                True
# 24             10.873493                True
# 25             10.991304               False
# 26             11.602571               False
# 27             10.894216               False
# 28             10.669155                True
# 29             11.081789               False
# 30             11.634374               False
# 31             10.364552                True
# 32             10.759989               False
# 33             11.754680               False
# 34             11.197409               False
# 35             10.756328               False
# 36             12.059702               False
# 37             10.334165                True
# 38             10.590465               False
# 39             11.334565               False
# 40             10.904827               False
# 41             11.092852               False
# 42             11.005175               False
# 43             10.563409               False
# 44             10.072499                True
# 45             10.129056               False
# 46             11.421702               False
# 47             10.995767               False
# 48             10.576185               False
# 49             10.439139               False
# 50             10.454053               False
# 51             10.292127               False
# 52             10.515160               False
# 53             10.132566               False
# 54             10.304454               False
# 55              9.917955                True
# 56             10.912743               False
# 57              9.852248                True
# 58             10.345303               False
# 59              9.915814               False
# {'best_epoch': 58, 'minimum_validation_mean_RMSE': 9.852247631514144, 'selection_formula': '(SM0_RMSE + SM20_RMSE) / 2', 'early_stopping_used': False}

# %% [markdown]
# ## 11. Reload best checkpoint from disk and reproduce validation metrics

# %%
best_path = Path(run_metadata["primary_checkpoint_path"])
observed_best_sha = sha256_file(best_path)
if observed_best_sha != run_metadata["primary_checkpoint_sha256"]:
    raise RuntimeError("STOP: validation-best checkpoint SHA256 mismatch")
payload = torch.load(best_path, map_location="cuda", weights_only=True)
verified_model = build_frozen_model(context.config).to("cuda")
verified_model.load_state_dict(payload["model_state_dict"], strict=True)
validation_loader = build_val_loader(context)
_, reproduced_metrics = prediction_rows_and_metrics(
    verified_model, validation_loader, torch.device("cuda"), context.config
)
saved_metrics = json.loads((supervised_dir / "validation_metrics.json").read_text(encoding="utf-8"))
metric_checks = {}
for target in ("SM_0", "SM_20"):
    for metric in ("rmse", "mae", "r2"):
        key = f"{target}_{metric}"
        difference = abs(reproduced_metrics["regression"][target][metric] - saved_metrics["regression"][target][metric])
        metric_checks[key] = difference
        if difference > 1e-10:
            raise RuntimeError(f"STOP: reproduced validation metric mismatch for {key}: {difference}")
artifact_verification = {
    "status": "PASS",
    "checkpoint_path": str(best_path),
    "checkpoint_sha256": observed_best_sha,
    "checkpoint_epoch": int(payload["epoch"]),
    "validation_metric_absolute_differences": metric_checks,
    "validation_sample_count": reproduced_metrics["n"],
    "test_loader_instantiated": False,
    "test_images_loaded": 0,
}
write_json(experiment_root / "artifact_verification.json", artifact_verification)
print(json.dumps(artifact_verification, indent=2))
del verified_model, validation_loader, payload
torch.cuda.empty_cache()
# Out:
# {
#   "status": "PASS",
#   "checkpoint_path": "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_best_regression.pth",
#   "checkpoint_sha256": "e2119a5b7a289925584fba8d3cd57040b7835461fc39d686bda464227de50020",
#   "checkpoint_epoch": 58,
#   "validation_metric_absolute_differences": {
#     "SM_0_rmse": 0.0,
#     "SM_0_mae": 0.0,
#     "SM_0_r2": 0.0,
#     "SM_20_rmse": 0.0,
#     "SM_20_mae": 0.0,
#     "SM_20_r2": 0.0
#   },
#   "validation_sample_count": 289,
#   "test_loader_instantiated": false,
#   "test_images_loaded": 0
# }

# %% [markdown]
# ## 12. P2 ImageNet-only vs P3 MobileViTv2 + VICReg on validation

# %%
p2_metrics = json.loads((p2_dir / "validation_metrics.json").read_text(encoding="utf-8"))
p2_metadata = json.loads((p2_dir / "run_metadata.json").read_text(encoding="utf-8"))
p3_metrics = json.loads((supervised_dir / "validation_metrics.json").read_text(encoding="utf-8"))
comparison = comparison_rows(
    p2_metrics,
    p3_metrics,
    (int(p2_metadata["complexity"]["parameters"]), int(p2_metadata["best_epoch"])),
    (int(run_metadata["complexity"]["parameters"]), int(run_metadata["best_epoch"])),
)
comparison_table = pd.DataFrame(comparison)
display(comparison_table)
comparison_table.to_csv(experiment_root / "validation_comparison.csv", index=False)
write_json(experiment_root / "validation_comparison.json", comparison)
p2_mean = comparison[0]["mean_RMSE"]
p3_mean = comparison[1]["mean_RMSE"]
if p3_mean < p2_mean:
    comparison_statement = "P3 has lower validation mean RMSE than P2 in this run."
elif p3_mean > p2_mean:
    comparison_statement = "P3 does not have lower validation mean RMSE than P2 in this run."
else:
    comparison_statement = "P2 and P3 have equal validation mean RMSE in this run."
print(comparison_statement)
# Out:
#                      experiment  best_epoch  SM_0_RMSE  SM_0_MAE   SM_0_R2  \
# 0  P2 MobileViTv2 ImageNet-only          60   8.094556  6.325553  0.925163
# 1       P3 MobileViTv2 + VICReg          58   9.849564  7.084054  0.889194
#
#    SM_20_RMSE  SM_20_MAE  SM_20_R2  mean_RMSE  mean_MAE  parameters
# 0    8.402766   6.497918  0.919088   8.248661  6.411735     1189189
# 1    9.854931   7.075376  0.888705   9.852248  7.079715     1189189
# P3 does not have lower validation mean RMSE than P2 in this run.

# %% [markdown]
# ## 13. Artifact preservation check and FINAL RUN SUMMARY

# %%
protected_after = {name: hash_tree(run_root / name) for name in PROTECTED_EXPERIMENTS}
if protected_before != protected_after:
    raise RuntimeError("STOP: a protected P0/P1/P2 artifact changed during P3")
write_json(experiment_root / "protected_artifacts_after_notebook.json", protected_after)

all_artifacts = sorted(str(path) for path in experiment_root.rglob("*") if path.is_file())
final_summary = {
    "status": "COMPLETE",
    "experiment_id": p3["experiment_id"],
    "SSL_checkpoint_path": ssl_metadata["encoder_checkpoint_path"],
    "SSL_checkpoint_SHA256": ssl_metadata["encoder_checkpoint_sha256"],
    "supervised_best_checkpoint_path": run_metadata["primary_checkpoint_path"],
    "supervised_best_checkpoint_SHA256": run_metadata["primary_checkpoint_sha256"],
    "best_epoch": run_metadata["best_epoch"],
    "minimum_validation_mean_RMSE": run_metadata["best_mean_validation_RMSE"],
    "parameters": run_metadata["complexity"]["parameters"],
    "SSL_training_seconds": ssl_metadata["training_duration_seconds"],
    "supervised_training_seconds": run_metadata["training_duration_seconds"],
    "git_commit": current_git_commit(REPO),
    "artifacts": all_artifacts,
    "P0_P1_P2_ARTIFACTS_UNCHANGED": True,
    "TEST_SET_OPENED": False,
    "TEST_LOADER_INSTANTIATED": False,
}
write_json(experiment_root / "FINAL_RUN_SUMMARY.json", final_summary)
print("=" * 80)
print("FINAL RUN SUMMARY")
print(json.dumps(final_summary, indent=2))
# Out:
# ================================================================================
# FINAL RUN SUMMARY
# {
#   "status": "COMPLETE",
#   "experiment_id": "P3_MOBILEVITV2_VICREG_LI_BESTREG",
#   "SSL_checkpoint_path": "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/mobilevitv2_vicreg_encoder_final.pth",
#   "SSL_checkpoint_SHA256": "32a1a62233d39bf6d5de5f803e7781be81e6a96851efc1531f87ec6f80ec5580",
#   "supervised_best_checkpoint_path": "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_best_regression.pth",
#   "supervised_best_checkpoint_SHA256": "e2119a5b7a289925584fba8d3cd57040b7835461fc39d686bda464227de50020",
#   "best_epoch": 58,
#   "minimum_validation_mean_RMSE": 9.852247631514144,
#   "parameters": 1189189,
#   "SSL_training_seconds": 39519.214298997,
#   "supervised_training_seconds": 8371.011681821,
#   "git_commit": "0a9438928aeac62ec0d8255b2b402c03dba6cf67",
#   "artifacts": [
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/artifact_verification.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/p2_p3_preflight_report.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/checkpoint_sha256.txt",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/mobilevitv2_vicreg_encoder_final.pth",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/pretraining_metadata.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/training_history.csv",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/unlabeled_manifest.csv",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/pretraining/vicreg_projector_final.pth",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/protected_artifacts_after_notebook.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/protected_artifacts_before.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/protected_artifacts_before_notebook.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/resolved_config.yaml",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/source_config.yaml",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/checkpoint_sha256.txt",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/epoch_60_final.pth",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/run_metadata.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/training_history.csv",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_best_regression.pth",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_metrics.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised/validation_predictions.csv",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/supervised_preflight_report.json",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/validation_comparison.csv",
#     "release-artifact://P3_MOBILEVITV2_VICREG_LI_BESTREG/validation_comparison.json"
#   ],
#   "P0_P1_P2_ARTIFACTS_UNCHANGED": true,
#   "TEST_SET_OPENED": false,
#   "TEST_LOADER_INSTANTIATED": false
# }
